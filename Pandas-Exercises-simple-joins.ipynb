# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the  datasets [cars1.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv) from the folder

# %%
cars1=pd.read_csv('cars1.csv')
cars2=pd.read_csv('cars2.csv')

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %% [markdown]
# ### Step 4. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.drop(columns=['Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13'],inplace=True)
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.count()
# Out:
# mpg             198
# cylinders       198
# displacement    198
# horsepower      198
# weight          198
# acceleration    198
# model           198
# origin          198
# car             198
# dtype: int64

# %%
cars2.count()
# Out:
# mpg             200
# cylinders       200
# displacement    200
# horsepower      200
# weight          200
# acceleration    200
# model           200
# origin          200
# car             200
# dtype: int64

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.merge(left=cars1 , right=cars2 , left_on ='car' , right_on = 'car', how ='inner',indicator=True)
cars.head()
# Out:
#    mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  acceleration_x  \
# 0   14.0            8             455          225      3086            10.0
# 1   25.0            4             110           87      2672            17.5
# 2   25.0            4             110           87      2672            17.5
# 3   23.0            4             120           88      2957            17.0
# 4   23.0            4             120           88      2957            17.0
#
#    model_x  origin_x                      car  mpg_y  cylinders_y  \
# 0       70         1  buick estate wagon (sw)   16.9            8
# 1       70         2              peugeot 504   19.0            4
# 2       70         2              peugeot 504   27.2            4
# 3       75         2              peugeot 504   19.0            4
# 4       75         2              peugeot 504   27.2            4
#
#    displacement_y horsepower_y  weight_y  acceleration_y  model_y  origin_y  \
# 0             350          155      4360            14.9       79         1
# 1             120           88      3270            21.9       76         2
# 2             141           71      3190            24.8       79         2
# 3             120           88      3270            21.9       76         2
# 4             141           71      3190            24.8       79         2
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %% [markdown]
# ### Step 7. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
arr=np.random.randint(15000,73000,cars.shape[0])
arr
# Out:
# array([31677, 58482, 15552, 67015, 70657, 69473, 55160, 71524, 31569,
#        64536, 56930, 32165, 48824, 18992, 39772, 37696, 47410, 45412,
#        57757, 55541, 68147, 37364, 58797, 67234, 34192, 24189, 38569,
#        51617, 44714, 64446, 69905, 65894, 39964, 45407, 41668, 70723])

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners']=arr

# %%
cars.head()
# Out:
#    mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  acceleration_x  \
# 0   14.0            8             455          225      3086            10.0
# 1   25.0            4             110           87      2672            17.5
# 2   25.0            4             110           87      2672            17.5
# 3   23.0            4             120           88      2957            17.0
# 4   23.0            4             120           88      2957            17.0
#
#    model_x  origin_x                      car  mpg_y  cylinders_y  \
# 0       70         1  buick estate wagon (sw)   16.9            8
# 1       70         2              peugeot 504   19.0            4
# 2       70         2              peugeot 504   27.2            4
# 3       75         2              peugeot 504   19.0            4
# 4       75         2              peugeot 504   27.2            4
#
#    displacement_y horsepower_y  weight_y  acceleration_y  model_y  origin_y  \
# 0             350          155      4360            14.9       79         1
# 1             120           88      3270            21.9       76         2
# 2             141           71      3190            24.8       79         2
# 3             120           88      3270            21.9       76         2
# 4             141           71      3190            24.8       79         2
#
#   _merge  owners
# 0   both   31677
# 1   both   58482
# 2   both   15552
# 3   both   67015
# 4   both   70657
